# %%
# The introduction of the game
'''
Journey to the West tells the story of tang Monk carrying Sun Wukong to the 
West for sutras. On the way, he experienced demons, ghosts and hardships and 
finally obtained the true sutras.
              author zixiong zhang              
'''
# the first story
def room_1():

    try:
        print("You're in room_1!\n")
        print("first story Save the Monkey King under the five elements mountain~")
        input('prompt = <Press any key to continue>\n')

        print("Tang Sanzang walking in the path of the five elements of the mountain, passing by a grim entrance, the entrance came the voice of help")

# you will see the king of monkey，decide whether you will enter the cave and have a look
        cmd = input('prompt = <press y see in the cave,No other keys >')
        if cmd.lower() != 'y':
            cmd = input("Someone called for help. As a monk, I'd better go in and have a look. Press Y to go in and see, press other keys, hurry on, do not go in:")
# the loop; if you choose false, you will involve into loop
            while True:
                if cmd.lower() != "y":
                    cmd = input("The monk is compassionate, think again! Press 1 to go in and see, press 2 to think about it and the other keys don't go in")
                    if cmd == '1':
                        break
                    elif cmd == "2":
                        print("rest and think about it.")
                        input('prompt = <Press any key to continue>\n')
                        print("think about it")
                        continue
                    else:
                        continue
# continue the game
        print("Tang Sanzang carefully into the cave, I saw a huge monkey tied to the rock, unable to move, this is the legendary king of all monsters - Sun Wukong.")
        input('prompt = <Press any key to continue>\n')


        print("After 500 years of destruction, sun Wukong is dying, but it's still daunting to see")
        input('prompt = <Press any key to continue>\n')


        print("On the way to the West, there are many demons and ghosts. Should we break the seal of the Monkey King and accept him as a disciple?")
        input('prompt = <Press any key to continue>\n')

# Consider the danger of the Monkey King. You will be failed if you choose a wrong choice
        choice = input("press c take him as a disciple, nothing else")

        if choice.lower() !="c":
            print("You chose not to take Sun Wukong as a disciple. Alone on the road to the West.")
            input('prompt = <Press any key to continue>\n')

            print("But there were too many monsters on the way to the west. Tang Monk went to fetch buddhist scriptures alone and fell into the jaws of the tiger and died")

            fail()
            return

        print("Congratulate you, choose to accept Sun Wukong as an apprentice, Sun Wukong combat effectiveness is super strong, but after all, also be a monster, whether to give him to wear tight hoop spell, limit his disorderly injury innocent")
        input('prompt = <Press any key to continue>\n')

# the choose
        cmd = input("a: To be safe, put a spell on Sun Wukong. Others: he is very assured, do not take the magic spell.")

        if cmd.lower() !="a":
            print("You are too careless, you chose not to wear the bones and muscles for Sun Wukong, sun Wukong has a demon attack, accidentally hurt Tang Sanzang.")

            fail()
            return
        else:
            print("Wearing the magic spell of sun Wukong, very obedient, smooth clearance.")
            input('prompt = <Press any key to continue>\n')

            room_2()
    except :
        print("error")


# the second story
def room_2():

    try:
        print("You're in room_2!\n")
        print("Second story Encounter bone spirit~")
        input('prompt = <Press any key to continue>\n')

        print("Deep in the mountains and forests, Sun Wukong went to other places to fight monsters, leaving Tang Sanzang alone in the circle of protection, at this time the girl's cry for help from afar.")
        input('prompt = <Press any key to continue>\n')
# If conditional grammar： whether to save the girl or not, wrong choice will fail
        cmd = input("Whether to go out of the protective circle to rescue the girl? y is yes,others is no")

        if cmd.lower() == "y":
            print("Tang Sanzang out of the protection circle, to the direction of the cry for help came, suddenly a gust of evil wind hit, swept away Tang Sanzang.")
            input('prompt = <Press any key to continue>\n')

            print("It turned out that the girl's cry for help was a trap set by the Ghost of Bones. Tang Sanzang was caught by the ghost of Bones in the cave and eaten")

            fail()
            return

        print("You chose to stay inside the protective circle and wait for sun Wukong to come back to see")
        input('prompt = <Press any key to continue>\n')

        print("After a while, Wukong comes back and Sanzang tells Wukong that it is by.")
        input('prompt = <Press any key to continue>\n')

        print("Wukong said, It must be from the side of the goblins. It must be from the side of the goblins. Just then, a woman happened to pass by and said she was looking for her daughter. She asked the Tibetan if he had seen her.")
        input('prompt = <Press any key to continue>\n')

        print("When sanzang was about to answer, Wukong shouted out a monster and took out a gang of golden cudgel to smash and kill the woman")
        input('prompt = <Press any key to continue>\n')

        print("Sanzang thought that the woman might not be a monster, and asked Wukong if he could see that she was a monster with his fiery eyes.")
        input('prompt = <Press any key to continue>\n')

        print("Wukong answered, I can't see some monsters, but I guess by feeling.")
        input('prompt = <Press any key to continue>\n')

        print("Sanzang thinks Wukong is too reckless, even if it is a monster, it may be a kind monster, without evidence without random injury innocent.")
        input('prompt = <Press any key to continue>\n')
# What should be done with the apprentice who killed the monster
        cmd = input("As punishment for Sun Wukong, please choose: 1:Sun Wukong has no master, drive him away, behind a person to the west to fetch scriptures.  other:Preach to Wukong, pay attention next time.")

        if cmd == "1":
            print("There were too many monsters on the Road to the west. Tang Monk went to fetch buddhist scriptures alone and fell into the jaws of the tiger and died")

            fail()
            return
        else:
            print("Sun Wukong after preaching, but also good convergence of some violent temper. The master and his disciples continued their pilgrimage to the West for buddhist scriptures.")
            input('prompt = <Press any key to continue>\n')
            room_3()

    except:
        print("error")


# the third story
def room_3():

    try:

        print("You're in room_3!\n")
        print("third Retrieve the scriptures~")
        input('prompt = <Press any key to continue>\n')

        print("Journey through many hardships, finally arrived in the western paradise.")
        input('prompt = <Press any key to continue>\n')

        print("Buddha asked Sanzang, see you have gone through untold hardships to come here, very hard, I just need a senior arhat, welfare is very good. If you want to stay, don't have to go back")
        input('prompt = <Press any key to continue>\n')

        print("What was the original intention of taking sutras in the West? It is to spread Buddhism and save all living beings. But to stay with Buddha as a senior arhat, the treatment is really very good, how to choose?")
        input('prompt = <Press any key to continue>\n')
# As a final temptation, think it over
        cmd = input("1:Stay and be an Arhat and enjoy your personal success. other: Take the true and false, return to the Tang Dynasty, spread Buddhism, universal living beings")

        if cmd == '1':
            print("I can't believe you chose to stay!")
            input('prompt = <Press any key to continue>\n')

            print("A bright personal future awaits you. Unfortunately, this is the Buddha's last test for you, and after so much suffering, you have lost your original purpose..")
            input('prompt = <Press any key to continue>\n')

            print("Buddha judges that you still need to practice and does not grant you sutras. Please go back.")

            fail()
            return
        else:
            print("Congratulations, you've been through a lot to keep your original heart.")
            input('prompt = <Press any key to continue>\n')
            print("Congratulations on getting the real book!!!!")

    except:
        print("error")





# the result of failture
def fail():
    print("You've failed, but thanks for playing!")
    input('prompt = <Press any key to exit>\n')


room_1()
# Out:
# You're in room_1!
#
# first story Save the Monkey King under the five elements mountain~
